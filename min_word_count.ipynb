# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajeshwari-Rudra/apache_beam-python/blob/main/min_word_count.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install apache-Beam
# !pip install --quiet apache-beam

# %%
import apache_beam as beam # importing apache_beam and then alias it as beam
import re # importing regular expression
p1 = beam.Pipeline() # defining a pipeline as p1 and initializing it 
min_word_count = (
    p1
    | beam.io.ReadFromText('key_benefits.csv',skip_header_lines=1) # reads the input from file and removes the header
    | beam.FlatMap(lambda line: re.findall(r"[a-zA-Z]+",line)) # finds the words 
    | beam.Map(lambda word: (word,1)) # pairing the words with 1
    | beam.CombinePerKey(sum) # Group and sum
    | beam.Map(lambda word_count:str(word_count)) # formatting the results
    | beam.io.WriteToText("output.txt") # writes the output to file
    
)
p1.run()

# %%
# !ls # returns the list of files
# Out:
# key_benefits.csv  outputs  output.txt  output.txt-00000-of-00001  sample_data

# %%
# !cat  output.txt-00000-of-00001  # concatinate the output file
# Out:
# ('d', 11269)
# ('e', 11219)
# ('a', 16116)
# ('c', 11214)
# ('f', 11085)
# ('bfa', 39)
# ('faf', 39)
# ('FAQ', 57)
# ('Accordion', 9)
# ('Product', 380)
# ('Info', 5)
# ('Add', 482)
# ('custom', 321)
# ('accordion', 10)
# ('with', 3624)
# ('answers', 36)
# ('to', 8456)
# ('commonly', 3)
# ('asked', 9)
# ('product', 1611)
# ('info', 68)
# ('questions', 89)
# ('Enable', 43)
# ('your', 8886)
# ('most', 239)
# ('popular', 59)
# ('question', 17)
# ('remain', 2)
# ('open', 42)
# ('Refund', 12)
# ('Policy', 5)
# ('Give', 102)
# ('customers', 2443)
# ('refund', 20)
# ('policy', 22)
# ('and', 8281)
# ('other', 243)
# ('frequently', 19)
# ('Page', 109)
# ('Builder', 31)
# ('Reduce', 158)
# ('support', 350)
# ('time', 1306)
# ('answer', 25)
# ('common', 19)
# ('such', 87)
# ('as', 764)
# ('returns', 85)
# ('cancellation', 10)
# ('shipping', 616)
# ('information', 214)
# ('in', 3025)
# ('an', 494)
# ('page', 738)
# ('eda', 30)
# ('b', 13033)
# ('Translate', 28)
# ('store', 1731)
# ...
