# %%
pip install apache-beam

# %%
# !pip install apache-beam[gcp,aws,test,docs]

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
downloaded = drive.CreateFile({'id':'1tR1_m6zwGUHhHOQd66JM13r8lMFA_E5k'})
downloaded.GetContentFile('gas_retail.csv')

# %%
downloaded = drive.CreateFile({'id':'1lVA7jckst-Wfa6cWjF0CiUD12kNuVxrf'})
downloaded.GetContentFile('top_restaurant.csv')

# %%
pip install apache-beam[interactive]

# %%
import apache_beam as beam
def groupbykey(test=None):
  # [START groupbyBatches]
  import apache_beam as beam

  with beam.Pipeline() as pipeline:
    produce_counts = (
        pipeline
        | beam.io.ReadFromText('gas_retail.csv')
        | 'Group counts per produce' >> beam.GroupIntoBatches()
        | beam.io.WriteToText(results.txt)
)
    
    # [END groupbyBatches]
    if test:
      test(produce_counts)

# %%
! ls
# Out:
# adc.json
# beam-temp-results.txt-31a68438727f11ebaf140242ac1c0002
# gas_retail.csv
# results.txt-00000-of-00001
# sample_data

# %%
! cat results.txt-00000-of-00001
# Out:
# ('01/02/1995', [1])
# ('01/09/1995', [1])
# ('01/16/1995', [1])
# ('01/23/1995', [1])
# ('01/30/1995', [1])
# ('02/06/1995', [1])
# ('02/13/1995', [1])
# ('02/20/1995', [1])
# ('02/27/1995', [1])
# ('03/06/1995', [1])
# ('03/13/1995', [1])
# ('03/20/1995', [1])
# ('03/27/1995', [1])
# ('04/03/1995', [1])
# ('04/10/1995', [1])
# ('04/17/1995', [1])
# ('04/24/1995', [1])
# ('05/01/1995', [1])
# ('05/08/1995', [1])
# ('05/15/1995', [1])
# ('05/22/1995', [1])
# ('05/29/1995', [1])
# ('06/05/1995', [1])
# ('06/12/1995', [1])
# ('06/19/1995', [1])
# ('06/26/1995', [1])
# ('07/03/1995', [1])
# ('07/10/1995', [1])
# ('07/17/1995', [1])
# ('07/24/1995', [1])
# ('07/31/1995', [1])
# ('08/07/1995', [1])
# ('08/14/1995', [1])
# ('08/21/1995', [1])
# ('08/28/1995', [1])
# ('09/04/1995', [1])
# ('09/11/1995', [1])
# ('09/18/1995', [1])
# ('09/25/1995', [1])
# ('10/02/1995', [1])
# ('10/09/1995', [1])
# ('10/16/1995', [1])
# ('10/23/1995', [1])
# ('10/30/1995', [1])
# ('11/06/1995', [1])
# ...
