# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajeshwari-Rudra/apache_beam-python/blob/main/superbowl_ads.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Code to read csv file into colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
# Authenticate the email-id
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# To import the csv that we uploaded it to google drive and giving the id of the file 
downloaded = drive.CreateFile({'id':'1b73yN7MjGytqSP5wimYAQmtByOvGGe8Y'}) # replace the id with id of file you want to access
downloaded.GetContentFile('superbowl-ads.csv');

# %%
# installs the apache-beam
! pip install --quiet -U apache-beam

# %%
# installs the apache-beam dependencies
! pip install apache-beam[gcp,aws,test,docs]
# Out:
# ...
#      |████████████████████████████████| 133kB 5.4MB/s
# ...
#      |████████████████████████████████| 440kB 14.8MB/s
# ...
#      |████████████████████████████████| 174kB 14.6MB/s
# ...
#      |████████████████████████████████| 256kB 17.6MB/s
# ...
#      |████████████████████████████████| 276kB 20.1MB/s
# ...
#      |████████████████████████████████| 174kB 11.8MB/s
# ...
#      |████████████████████████████████| 92kB 8.6MB/s
# ...
#      |████████████████████████████████| 153kB 28.2MB/s
# ...
#      |████████████████████████████████| 71kB 7.1MB/s
# ...
#      |████████████████████████████████| 184kB 20.4MB/s
# ...
#      |████████████████████████████████| 3.0MB 20.8MB/s
# ...
#      |████████████████████████████████| 51kB 4.8MB/s
# ...
#      |████████████████████████████████| 163kB 45.1MB/s
# ...
#      |████████████████████████████████| 235kB 39.4MB/s
# ...
#      |████████████████████████████████| 7.5MB 53.4MB/s
# ...
#      |████████████████████████████████| 71kB 8.4MB/s
# ...
#      |████████████████████████████████| 512kB 49.0MB/s
# ...

# %%
import os
# for importing apache_beam and naming it as beam 
import apache_beam as beam 
# for importing regular expressions
import re 
# defining a pipeline named p1 and initializing it
with beam.Pipeline() as pipeline:
 word_counts =(
    pipeline
    | beam.io.ReadFromText('superbowl-ads.csv',skip_header_lines=1)# reads the input text file and skips the header part.
    | beam.FlatMap(lambda line: re.findall(r"[a-zA-Z']+", line)) #Using a regular expression to iterate over all the words in a line that stored in a collection as a tuple of (word,count)
    # create key-value pairs where the value is 1, in this way we can group by the same word
    # while adding those 1's and get the counts for every word.
    |beam.Map(lambda word:(word, 1))
    # Group by key while combining the value using the sum()function.
    | beam.CombinePerKey(sum)
    # formatting the result into a string so we can write to a file
    | beam.Map(lambda word_count: str(word_count))
    # Finally, write the results to a output file.
    | beam.io.WriteToText("output.txt")
)
pipeline.run()

# %%
ls
# Out:
# adc.json  output.txt-00000-of-00001  sample_data/  superbowl-ads.csv

# %%
cat output.txt-00000-of-00001 # output file
# Out:
# ('Car', 88)
# ('Chrysler', 5)
# ('Scuba', 1)
# ('Diver', 1)
# ('A', 195)
# ('scuba', 1)
# ('diver', 1)
# ('in', 170)
# ('a', 455)
# ('dreamy', 1)
# ('sequence', 1)
# ('with', 107)
# ('groovy', 1)
# ('music', 11)
# ('introduces', 1)
# ('as', 56)
# ('the', 615)
# ('Possible', 1)
# ('Dream', 2)
# ('Pontiac', 3)
# ('Humbler', 1)
# ('young', 9)
# ('man', 53)
# ('pulled', 2)
# ('up', 29)
# ('his', 108)
# ('GTO', 1)
# ('to', 269)
# ('drive', 10)
# ('restaurant', 5)
# ('dramatic', 1)
# ('and', 234)
# ('exhaust', 3)
# ('noise', 2)
# ('background', 4)
# ('pulling', 4)
# ('knob', 1)
# ('activate', 1)
# ('vacuum', 1)
# ('operated', 1)
# ('drowning', 1)
# ('out', 36)
# ('then', 30)
# ('off', 18)
# ('Security', 3)
# ('Master', 4)
# ('Lock', 3)
# ('Rifle', 1)
# ('attempts', 2)
# ('break', 4)
# ('rifle', 1)
# ('He', 22)
# ('fails', 3)
# ('but', 21)
# ('does', 8)
# ('put', 2)
# ('bullet', 1)
# ('hole', 3)
# ('lock', 1)
# ('Copy', 1)
# ('Xerox', 2)
# ('Monks', 1)
# ('monk', 1)
# ('must', 1)
# ...
